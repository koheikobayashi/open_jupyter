# %%
import pandas as pd

hospital = pd.read_csv('./mydata - hospital.csv')
hos1 = hospital["Location"].values.tolist()

# %%
hos1
# Out:
# ['奥州市水沢東大通一丁目5番30号',
#  '盛岡市青山一丁目25番１号',
#  '盛岡市内丸19番１号',
#  '盛岡市加賀野三丁目14番１号',
#  '盛岡市下米内二丁目４番12号',
#  '盛岡市下ノ橋町６番14号',
#  '盛岡市肴町２番28号',
#  '盛岡市館向町４番８号',
#  '盛岡市中太田泉田28番地',
#  '盛岡市名須川町29番２号',
#  '盛岡市高松四丁目20番40号',
#  '盛岡市月が丘一丁目29番15号',
#  '盛岡市本町通一丁目12番７号',
#  '盛岡市本宮一丁目６番12号',
#  '盛岡市繋字尾入野64番地９',
#  '盛岡市東黒石野三丁目２番１号',
#  '盛岡市渋民字大前田53番地２',
#  '盛岡市下田字陣場41-10',
#  '盛岡市東見前第６地割40番地１',
#  '盛岡市手代森第９地割70番地１',
#  '盛岡市津志田第26地割30－１',
#  '盛岡市津志田第13地割18番地４',
#  '盛岡市永井第12地割10番地',
#  '盛岡市好摩字夏間木70－190',
#  '盛岡市西松園三丁目22番３号',
#  '盛岡市上田一丁目４番１号',
#  '盛岡市三本柳第６地割１番地１',
#  '盛岡市本宮五丁目15番1号',
#  '滝沢市鵜飼笹森42番地２号',
#  '滝沢市大釜吉水103番地１',
#  '紫波郡紫波町犬淵字南谷地110番地5',
#  '紫波郡矢巾町大字藤沢第２地割29番地１',
#  '紫波郡矢巾町広宮沢第１地割字２-181',
#  '岩手郡雫石町南畑第32地割字南桝沢265番地',
#  '岩手郡雫石町第22地割字七ツ森16番地243',
#  '紫波郡矢巾町大字煙山第24地割１番',
#  '岩手郡葛巻町葛巻第16地割１番地１',
#  '八幡平市田頭第22地割79番地１',
#  '八幡平市柏台二丁目８番２号',
#  '花巻市花城町４番28号',
#  '花巻市東宮野目第13地割１番地１',
#  '花巻市諏訪500',
#  '花巻市湯口字志戸平14番地１',
#  '花巻市石鳥谷町新堀第15地割23番地',
#  '花巻市東和町安俵６区75番地１',
#  '遠野市青笹町中沢第５地割５番地の１',
#  '遠野市松崎町白岩第14地割74番地',
#  '北上市花園町一丁目６番８号',
#  '北上市村崎野第16地割89番地１',
#  '北上市村崎野第17地割10番地',
#  '和賀郡西和賀町沢内字大野１３地割３番地１２',
#  '奥州市水沢字龍ケ馬場61番地',
#  '奥州市水沢大手町三丁目１番地',
#  '奥州市水沢佐倉河字慶徳27番地１',
#  '奥州市水沢南町８番10号',
#  '奥州市水沢羽田町字水無沢495番地の２',
#  '奥州市前沢古城字丑沢上野100番地',
#  '奥州市胆沢南都田字大持40番地',
#  '奥州市江刺西大通り５番23号',
#  '一関市山目字泥田山下48',
#  '一関市狐禅寺字大平17',
#  '一関市狐禅寺字大平17',
#  '一関市大手町３番36号',
#  '一関市田村町６番３号',
#  '一関市八幡町２番43号',
#  '一関市大東町大原字川内128番地',
#  '一関市千厩町千厩字草井沢32番地１',
#  '一関市東山町松川字卯入道121番地',
#  '一関市藤沢町藤沢字町裏52番地２',
#  '陸前高田市高田町大隅８番地６',
#  '陸前高田市高田町字太田56',
#  '大船渡市大船渡町字山馬越10番地１',
#  '釜石市小佐野町四丁目３番７号',
#  '釜石市野田町一丁目16番32号',
#  '釜石市定内町四丁目７番１号',
#  '釜石市甲子町第10地割483番地６',
#  '釜石市大渡町三丁目15番26号',
#  '大槌町小鎚第23地割字寺野１番地１',
#  '宮古市板屋一丁目６番36号',
#  '宮古市山口五丁目３番20号',
#  '宮古市保久田８番37号',
#  '下閉伊郡山田町飯岡第１地割21番地１',
#  '宮古市崎鍬ケ崎第１地割11番地26',
#  '下閉伊郡岩泉町岩泉字中家19番地１',
#  '久慈市源道第12地割111番',
#  '久慈市湊町第17地割100番地',
#  '九戸郡洋野町種市第23地割27番地２',
#  '久慈市旭町第10地割１番',
#  '二戸市堀野字大川原毛38番地２',
#  '九戸郡軽米町大字軽米第２地割54番地５',
#  '二戸郡一戸町一戸字砂森60番地１']

# %%
import requests
from bs4 import BeautifulSoup
import time
from tqdm import tqdm


def get_lat_lon_from_address(address_l):
    """
    address_lにlistの形で住所を入れてあげると、latlonsという入れ子上のリストで緯度経度のリストを返す関数。
    >>>>get_lat_lon_from_address(['東京都文京区本郷7-3-1','東京都文京区湯島３丁目３０−１'])
    [['35.712056', '139.762775'], ['35.707771', '139.768205']]
    """
    url = 'http://www.geocoding.jp/api/'
    latlons = []
    for address in tqdm(address_l):
        payload = {'q': address}
        r = requests.get(url, params=payload)
        ret = BeautifulSoup(r.content,'lxml')
        if ret.find('error'):
            raise ValueError(f"Invalid address submitted. {address}")
        else:
            lat = ret.find('lat').string
            lon = ret.find('lng').string
            latlons.append([lat,lon])
            time.sleep(10)
    return latlons

# %%
lons = get_lat_lon_from_address(hos1)
# Out:
#   0%|          | 0/91 [00:00<?, ?it/s]
#
#   1%|          | 1/91 [00:13<20:03, 13.38s/it]
#
#   2%|▏         | 2/91 [00:24<18:58, 12.79s/it]
#
#   3%|▎         | 3/91 [00:35<17:54, 12.21s/it]
#
#   4%|▍         | 4/91 [00:48<18:03, 12.45s/it]
#
#   5%|▌         | 5/91 [01:01<17:53, 12.49s/it]
#
#   7%|▋         | 6/91 [01:15<18:18, 12.92s/it]
#
#   8%|▊         | 7/91 [01:27<17:56, 12.82s/it]
#
#   9%|▉         | 8/91 [01:38<16:55, 12.24s/it]
#
#  10%|▉         | 9/91 [01:49<16:07, 11.79s/it]
#
#  11%|█         | 10/91 [02:02<16:23, 12.14s/it]
#
#  12%|█▏        | 11/91 [02:15<16:43, 12.54s/it]
#
#  13%|█▎        | 12/91 [02:29<16:46, 12.74s/it]
#
#  14%|█▍        | 13/91 [02:42<16:39, 12.82s/it]
#
#  15%|█▌        | 14/91 [02:52<15:39, 12.20s/it]
#
#  16%|█▋        | 15/91 [03:03<14:57, 11.81s/it]
#
#  18%|█▊        | 16/91 [03:16<15:09, 12.12s/it]
#
#  19%|█▊        | 17/91 [03:27<14:25, 11.69s/it]
#
#  20%|█▉        | 18/91 [03:40<14:41, 12.08s/it]
#
#  21%|██        | 19/91 [03:51<14:02, 11.71s/it]
#
#  22%|██▏       | 20/91 [04:04<14:38, 12.37s/it]
#
#  23%|██▎       | 21/91 [04:17<14:34, 12.50s/it]
#
#  24%|██▍       | 22/91 [04:30<14:37, 12.71s/it]
#
#  25%|██▌       | 23/91 [04:44<14:38, 12.91s/it]
#
#  26%|██▋       | 24/91 [04:55<13:42, 12.28s/it]
#
#  27%|██▋       | 25/91 [05:08<13:46, 12.52s/it]
#
#  29%|██▊       | 26/91 [05:21<13:43, 12.67s/it]
#
#  30%|██▉       | 27/91 [05:34<13:33, 12.71s/it]
#
#  31%|███       | 28/91 [05:46<13:06, 12.49s/it]
#
#  32%|███▏      | 29/91 [05:56<12:22, 11.97s/it]
#
#  33%|███▎      | 30/91 [06:07<11:51, 11.67s/it]
#
#  34%|███▍      | 31/91 [06:19<11:45, 11.76s/it]
#
#  35%|███▌      | 32/91 [06:30<11:17, 11.48s/it]
#
#  36%|███▋      | 33/91 [06:43<11:36, 12.01s/it]
#
#  37%|███▋      | 34/91 [06:56<11:39, 12.28s/it]
#
#  38%|███▊      | 35/91 [07:09<11:37, 12.45s/it]
#
#  40%|███▉      | 36/91 [07:20<10:57, 11.95s/it]
#
#  41%|████      | 37/91 [07:31<10:27, 11.62s/it]
#
#  42%|████▏     | 38/91 [07:43<10:32, 11.94s/it]
#
#  43%|████▎     | 39/91 [07:56<10:35, 12.22s/it]
#
#  44%|████▍     | 40/91 [08:09<10:29, 12.35s/it]
#
#  45%|████▌     | 41/91 [08:20<09:56, 11.93s/it]
#
#  46%|████▌     | 42/91 [08:32<09:54, 12.13s/it]
#
#  47%|████▋     | 43/91 [08:44<09:31, 11.90s/it]
#
#  48%|████▊     | 44/91 [08:55<09:04, 11.57s/it]
#
#  49%|████▉     | 45/91 [09:07<09:07, 11.89s/it]
#
#  51%|█████     | 46/91 [09:20<09:13, 12.29s/it]
#
#  52%|█████▏    | 47/91 [09:35<09:25, 12.84s/it]
#
#  53%|█████▎    | 48/91 [09:47<09:09, 12.77s/it]
#
#  54%|█████▍    | 49/91 [10:00<08:55, 12.74s/it]
#
#  55%|█████▍    | 50/91 [10:11<08:16, 12.12s/it]
#
#  56%|█████▌    | 51/91 [10:21<07:49, 11.74s/it]
#
#  57%|█████▋    | 52/91 [10:32<07:26, 11.45s/it]
#
#  58%|█████▊    | 53/91 [10:45<07:31, 11.89s/it]
#
#  59%|█████▉    | 54/91 [10:56<07:07, 11.56s/it]
#
#  60%|██████    | 55/91 [11:09<07:07, 11.89s/it]
#
#  62%|██████▏   | 56/91 [11:19<06:43, 11.52s/it]
#
#  63%|██████▎   | 57/91 [11:30<06:24, 11.30s/it]
#
#  64%|██████▎   | 58/91 [11:43<06:24, 11.66s/it]
#
#  65%|██████▍   | 59/91 [11:53<06:04, 11.39s/it]
#
#  66%|██████▌   | 60/91 [12:05<05:55, 11.46s/it]
#
#  67%|██████▋   | 61/91 [12:16<05:37, 11.26s/it]
#
#  68%|██████▊   | 62/91 [12:27<05:24, 11.18s/it]
#
#  69%|██████▉   | 63/91 [12:37<05:10, 11.08s/it]
#
#  70%|███████   | 64/91 [12:51<05:14, 11.65s/it]
#
#  71%|███████▏  | 65/91 [13:04<05:19, 12.29s/it]
#
#  73%|███████▎  | 66/91 [13:15<04:56, 11.87s/it]
#
#  74%|███████▎  | 67/91 [13:26<04:37, 11.57s/it]
#
#  75%|███████▍  | 68/91 [13:39<04:38, 12.10s/it]
#
#  76%|███████▌  | 69/91 [13:52<04:32, 12.36s/it]
#
#  77%|███████▋  | 70/91 [14:04<04:12, 12.02s/it]
#
#  78%|███████▊  | 71/91 [14:17<04:07, 12.39s/it]
#
#  79%|███████▉  | 72/91 [14:28<03:47, 11.99s/it]
#
#  80%|████████  | 73/91 [14:39<03:29, 11.64s/it]
#
#  81%|████████▏ | 74/91 [14:51<03:23, 11.98s/it]
#
#  82%|████████▏ | 75/91 [15:02<03:06, 11.65s/it]
#
#  84%|████████▎ | 76/91 [15:14<02:54, 11.66s/it]
#
#  85%|████████▍ | 77/91 [15:27<02:48, 12.01s/it]
#
#  86%|████████▌ | 78/91 [15:39<02:38, 12.19s/it]
#
#  87%|████████▋ | 79/91 [15:53<02:29, 12.46s/it]
#
#  88%|████████▊ | 80/91 [16:05<02:18, 12.58s/it]
#
#  89%|████████▉ | 81/91 [16:19<02:08, 12.82s/it]
#
#  90%|█████████ | 82/91 [16:32<01:55, 12.83s/it]
#
#  91%|█████████ | 83/91 [16:42<01:37, 12.21s/it]
#
#  92%|█████████▏| 84/91 [16:53<01:22, 11.79s/it]
#
#  93%|█████████▎| 85/91 [17:05<01:10, 11.73s/it]
#
#  95%|█████████▍| 86/91 [17:16<00:57, 11.45s/it]
#
#  96%|█████████▌| 87/91 [17:29<00:47, 11.90s/it]
#
#  97%|█████████▋| 88/91 [17:39<00:34, 11.51s/it]
#
#  98%|█████████▊| 89/91 [17:50<00:22, 11.25s/it]
#
#  99%|█████████▉| 90/91 [18:00<00:11, 11.07s/it]
#
# 100%|██████████| 91/91 [18:13<00:00, 11.63s/it]

# %%
lons.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-06ca6150f828> in <module>
# ----> 1 lons.type
#
# AttributeError: 'list' object has no attribute 'type'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster
import geopandas as gpd
from branca.colormap import LinearColormap
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


map1 = folium.Map(location=[39.250285, 141.636919], zoom_start=11.5)
FastMarkerCluster(data=lons).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lons
# Out:
# [['39.152619', '141.131479'],
#  ['39.722672', '141.111341'],
#  ['39.704942', '141.152001'],
#  ['39.707649', '141.169673'],
#  ['39.718046', '141.176052'],
#  ['39.697155', '141.149081'],
#  ['39.698028', '141.153021'],
#  ['39.716261', '141.130055'],
#  ['39.700706', '141.110363'],
#  ['39.711693', '141.154265'],
#  ['39.730836', '141.134902'],
#  ['39.734004', '141.113718'],
#  ['39.707577', '141.15425'],
#  ['39.690404', '141.140827'],
#  ['39.68907', '141.024205'],
#  ['39.748551', '141.158338'],
#  ['39.837654', '141.164913'],
#  ['39.836637', '141.154496'],
#  ['39.642168', '141.168494'],
#  ['39.658378', '141.185491'],
#  ['39.672103', '141.15622'],
#  ['39.656446', '141.156058'],
#  ['39.658509', '141.137185'],
#  ['39.875063', '141.165343'],
#  ['39.756577', '141.162761'],
#  ['39.713433', '141.145816'],
#  ['39.661489', '141.167492'],
#  ['39.68935', '141.124483'],
#  ['39.735527', '141.091154'],
#  ['39.698802', '141.056901'],
#  ['39.510002', '141.158524'],
#  ['39.618525', '141.163684'],
#  ['39.628568', '141.085186'],
#  ['39.638815', '140.940098'],
#  ['39.70376', '141.012918'],
#  ['39.610434', '141.120682'],
#  ['40.040119', '141.438921'],
#  ['39.91448', '141.090051'],
#  ['39.916025', '140.982036'],
#  ['39.390003', '141.116722'],
#  ['39.40893', '141.124205'],
#  ['39.369966', '141.109718'],
#  ['39.418985', '141.012503'],
#  ['39.497004', '141.16867'],
#  ['39.383922', '141.223815'],
#  ['39.315269', '141.579978'],
#  ['39.339187', '141.541599'],
#  ['39.288652', '141.121649'],
#  ['39.324357', '141.122558'],
#  ['39.330011', '141.104996'],
#  ['39.372149', '140.761582'],
#  ['39.123052', '141.135284'],
#  ['39.146594', '141.138877'],
#  ['39.14334', '141.148767'],
#  ['39.136157', '141.143585'],
#  ['39.129477', '141.211074'],
#  ['39.071392', '141.127041'],
#  ['39.12902', '141.067926'],
#  ['39.194128', '141.172502'],
#  ['38.939517', '141.115451'],
#  ['38.936175', '141.170258'],
#  ['38.936175', '141.170258'],
#  ['38.929527', '141.134872'],
#  ['38.930064', '141.132814'],
#  ['38.927011', '141.13302'],
#  ['39.01663', '141.395166'],
#  ['38.928367', '141.34341'],
#  ['38.961252', '141.249851'],
#  ['38.858154', '141.349639'],
#  ['39.033071', '141.636919'],
#  ['39.020454', '141.641265'],
#  ['39.072631', '141.707478'],
#  ['39.261644', '141.836338'],
#  ['39.257275', '141.827463'],
#  ['39.250285', '141.835872'],
#  ['39.255312', '141.816577'],
#  ['39.273576', '141.878467'],
#  ['39.358675', '141.879961'],
#  ['39.634707', '141.917395'],
#  ['39.655771', '141.932148'],
#  ['39.644389', '141.947171'],
#  ['39.458148', '141.951119'],
#  ['39.658868', '141.948045'],
#  ['39.847589', '141.795035'],
#  ['40.200662', '141.782141'],
#  ['40.200495', '141.790306'],
#  ['40.409845', '141.719131'],
#  ['40.200937', '141.777185'],
#  ['40.299997', '141.306024'],
#  ['40.317186', '141.478404'],
#  ['40.207532', '141.305037']]
